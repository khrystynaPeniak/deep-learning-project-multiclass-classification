# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import cv2
import os

import matplotlib.pyplot as plt
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
import albumentations as A
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB3, EfficientNetB0, ResNet50
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_DIR = "/content/drive/MyDrive/mashrooms-vision/"
IMG_DIR = DATASET_DIR + "dataset/dataset/"

train_df = pd.read_csv(DATASET_DIR + "train.csv")
test_df = pd.read_csv(DATASET_DIR + "test.csv")

# %%
train_df.head()
# Out:
#    Image  Mushroom
# 0      1         0
# 1      2         0
# 2      3         0
# 3      4         0
# 4      5         0

# %%
train_df.shape
# Out:
# (2365, 2)

# %%
class_counts = train_df['Mushroom'].value_counts()

plt.figure(figsize=(8,5))
plt.bar(class_counts.index.astype(str), class_counts.values)

plt.xlabel("Class")
plt.ylabel("Amout")
plt.xticks(rotation=0)
plt.show()

# %%
classes = train_df['Mushroom'].unique()

plt.figure(figsize=(12, 6))

for i, cls in enumerate(classes):
    sample = train_df[train_df['Mushroom'] == cls].iloc[4]
    img_name = f"{sample['Image']:05d}.jpg"

    img_path = os.path.join(IMG_DIR, img_name)

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.subplot(1, len(classes), i + 1)
    plt.imshow(img)
    plt.title(f"Class: {cls}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
bad = []
for file in os.listdir(IMG_DIR):
    img = cv2.imread(os.path.join(IMG_DIR, file))
    if img is None:
        bad.append(file)
bad
# Out:
# []

# %% [markdown]
# ##Data splitting for model training

# %%
train_unsampled, val = train_test_split(train_df, stratify=train_df['Mushroom'], test_size=0.2, random_state=42)
val, test = train_test_split(val, stratify=val['Mushroom'], test_size=0.25, random_state=42)

# %%
def pathify(df):
    df['Image'] = df['Image'].apply(lambda x: IMG_DIR + str(x).zfill(5) + ".jpg")
    return df

train_unsampled = pathify(train_unsampled)
val = pathify(val)
test = pathify(test)

# %%
train_unsampled
# Out:
#                                                   Image  Mushroom
# 370   /content/drive/MyDrive/mashrooms-vision/datase...         1
# 134   /content/drive/MyDrive/mashrooms-vision/datase...         0
# 904   /content/drive/MyDrive/mashrooms-vision/datase...         3
# 380   /content/drive/MyDrive/mashrooms-vision/datase...         1
# 2230  /content/drive/MyDrive/mashrooms-vision/datase...         9
# ...                                                 ...       ...
# 1351  /content/drive/MyDrive/mashrooms-vision/datase...         5
# 1004  /content/drive/MyDrive/mashrooms-vision/datase...         4
# 223   /content/drive/MyDrive/mashrooms-vision/datase...         0
# 886   /content/drive/MyDrive/mashrooms-vision/datase...         3
# 759   /content/drive/MyDrive/mashrooms-vision/datase...         3
#
# [1892 rows x 2 columns]

# %%
train_unsampled['Mushroom'].unique()
# Out:
# array([1, 0, 3, 9, 7, 2, 5, 8, 6, 4])

# %%
train_unsampled['Mushroom'].value_counts()
# Out:
# Mushroom
# 1    192
# 9    192
# 8    192
# 7    192
# 2    192
# 5    192
# 0    190
# 6    190
# 4    182
# 3    178
# Name: count, dtype: int64

# %% [markdown]
# ##Dataset preparation

# %%
BATCH_SIZE = 32
IMAGE_SIZE = (224,224)

# %%
def load_image(image_path, label):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, IMAGE_SIZE)
    #image = image / 255.0 #only for b0
    return image, label

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_unsampled['Image'].values, train_unsampled['Mushroom'].values))
train_ds = train_ds.shuffle(len(train_unsampled)).map(load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val['Image'].values, val['Mushroom'].values))
val_ds = val_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((test['Image'].values, test['Mushroom'].values))
test_ds = test_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ##Dataset inspection and sanity check

# %%
for x, y in train_ds.take(1):
    print("Batch images:", x.shape)
    print("Batch labels:", y.numpy())
# Out:
# Batch images: (32, 224, 224, 3)
# Batch labels: [6 9 1 1 8 5 1 4 1 5 5 8 1 9 7 3 2 3 8 9 5 5 9 3 6 0 8 0 7 3 8 2]

# %%
num_classes = train_unsampled['Mushroom'].nunique()
print("Number of classes:", num_classes)

print("Train classes:", train_unsampled['Mushroom'].unique())
print("Val classes:", val['Mushroom'].unique())
print("Test classes:", test['Mushroom'].unique())

print("Train distribution:\n", train_unsampled['Mushroom'].value_counts())
print("Val distribution:\n", val['Mushroom'].value_counts())
print("Test distribution:\n", test['Mushroom'].value_counts())
# Out:
# Number of classes: 10
# Train classes: [1 0 3 9 7 2 5 8 6 4]
# Val classes: [5 2 1 9 0 8 7 6 3 4]
# Test classes: [6 2 8 5 9 4 7 3 0 1]
# Train distribution:
#  Mushroom
# 1    192
# 9    192
# 8    192
# 7    192
# 2    192
# 5    192
# 0    190
# 6    190
# 4    182
# 3    178
# Name: count, dtype: int64
# Val distribution:
#  Mushroom
# 5    36
# 2    36
# 1    36
# 9    36
# 0    36
# 8    36
# 7    36
# 6    36
# 3    33
# 4    33
# Name: count, dtype: int64
# Test distribution:
#  Mushroom
# 6    12
# 2    12
# 8    12
# 5    12
# 9    12
# 4    12
# 7    12
# 0    12
# 1    12
# 3    11
# Name: count, dtype: int64

# %% [markdown]
# ##CNN models
# ####EfficientNetB0

# %%
data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

base_model5 = tf.keras.applications.EfficientNetB0(
    include_top=False,
    input_shape=(224,224,3),
    weights="imagenet"
)


base_model5.trainable = True
for layer in base_model5.layers[:40]:
    layer.trainable = False

model5 = tf.keras.Sequential([
    data_augment,
    base_model5,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(10, activation="softmax")
])

model5.compile(
    optimizer=tf.keras.optimizers.Adam(3e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3),
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True)
]

history = model5.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks
)

test_loss, test_acc = model5.evaluate(test_ds)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 56s 296ms/step - accuracy: 0.1351 - loss: 3.0284 - val_accuracy: 0.1017 - val_loss: 2.3398 - learning_rate: 3.0000e-04
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 0.2946 - loss: 2.3451 - val_accuracy: 0.1299 - val_loss: 2.3227 - learning_rate: 3.0000e-04
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 247ms/step - accuracy: 0.3295 - loss: 2.0936 - val_accuracy: 0.1186 - val_loss: 2.3484 - learning_rate: 3.0000e-04
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 263ms/step - accuracy: 0.4188 - loss: 1.7522 - val_accuracy: 0.1186 - val_loss: 2.3930 - learning_rate: 3.0000e-04
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 248ms/step - accuracy: 0.4520 - loss: 1.6459 - val_accuracy: 0.1356 - val_loss: 2.5468 - learning_rate: 3.0000e-04
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.5369 - loss: 1.3958 - val_accuracy: 0.2062 - val_loss: 2.4327 - learning_rate: 9.0000e-05
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 247ms/step - accuracy: 0.5357 - loss: 1.3645 - val_accuracy: 0.3559 - val_loss: 1.9125 - learning_rate: 9.0000e-05
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.5319 - loss: 1.3586 - val_accuracy: 0.4689 - val_loss: 1.5725 - learning_rate: 9.0000e-05
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.5303 - loss: 1.3289 - val_accuracy: 0.5198 - val_loss: 1.3591 - learning_rate: 9.0000e-05
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 268ms/step - accuracy: 0.5640 - loss: 1.2802 - val_accuracy: 0.6130 - val_loss: 1.1432 - learning_rate: 9.0000e-05
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 244ms/step - accuracy: 0.6067 - loss: 1.2199 - val_accuracy: 0.6045 - val_loss: 1.1488 - learning_rate: 9.0000e-05
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.6237 - loss: 1.1510 - val_accuracy: 0.6045 - val_loss: 1.1126 - learning_rate: 9.0000e-05
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 244ms/step - accuracy: 0.6236 - loss: 1.1102 - val_accuracy: 0.6299 - val_loss: 1.1568 - learning_rate: 9.0000e-05
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 245ms/step - accuracy: 0.6138 - loss: 1.1135 - val_accuracy: 0.6412 - val_loss: 1.0829 - learning_rate: 9.0000e-05
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.6488 - loss: 1.0137 - val_accuracy: 0.6525 - val_loss: 1.0451 - learning_rate: 9.0000e-05
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.6620 - loss: 0.9581 - val_accuracy: 0.6667 - val_loss: 0.9984 - learning_rate: 9.0000e-05
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 250ms/step - accuracy: 0.6543 - loss: 1.0373 - val_accuracy: 0.6328 - val_loss: 1.0883 - learning_rate: 9.0000e-05
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 244ms/step - accuracy: 0.6630 - loss: 1.0195 - val_accuracy: 0.6243 - val_loss: 1.0933 - learning_rate: 9.0000e-05
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 244ms/step - accuracy: 0.6793 - loss: 0.9831 - val_accuracy: 0.5395 - val_loss: 1.3485 - learning_rate: 9.0000e-05
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.6976 - loss: 0.8916 - val_accuracy: 0.6582 - val_loss: 0.9924 - learning_rate: 2.7000e-05
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.7126 - loss: 0.8580 - val_accuracy: 0.6808 - val_loss: 0.9009 - learning_rate: 2.7000e-05
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.7081 - loss: 0.8861 - val_accuracy: 0.7175 - val_loss: 0.8842 - learning_rate: 2.7000e-05
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 270ms/step - accuracy: 0.6881 - loss: 0.8790 - val_accuracy: 0.7401 - val_loss: 0.8465 - learning_rate: 2.7000e-05
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 245ms/step - accuracy: 0.6821 - loss: 0.8806 - val_accuracy: 0.7119 - val_loss: 0.8455 - learning_rate: 2.7000e-05
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 245ms/step - accuracy: 0.7100 - loss: 0.8528 - val_accuracy: 0.6977 - val_loss: 0.9435 - learning_rate: 2.7000e-05
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 243ms/step - accuracy: 0.7179 - loss: 0.8639 - val_accuracy: 0.7147 - val_loss: 0.8702 - learning_rate: 2.7000e-05
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 244ms/step - accuracy: 0.7044 - loss: 0.8548 - val_accuracy: 0.7514 - val_loss: 0.8109 - learning_rate: 2.7000e-05
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 244ms/step - accuracy: 0.6968 - loss: 0.8645 - val_accuracy: 0.7175 - val_loss: 0.8259 - learning_rate: 2.7000e-05
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 267ms/step - accuracy: 0.7070 - loss: 0.8271 - val_accuracy: 0.7429 - val_loss: 0.8034 - learning_rate: 2.7000e-05
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 243ms/step - accuracy: 0.7096 - loss: 0.8590 - val_accuracy: 0.7316 - val_loss: 0.8027 - learning_rate: 2.7000e-05
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 246ms/step - accuracy: 0.7320 - loss: 0.8055 - val_accuracy: 0.7090 - val_loss: 0.8519 - learning_rate: 2.7000e-05
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.7150 - loss: 0.8367 - val_accuracy: 0.7203 - val_loss: 0.8495 - learning_rate: 2.7000e-05
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 266ms/step - accuracy: 0.7207 - loss: 0.8178 - val_accuracy: 0.7345 - val_loss: 0.8076 - learning_rate: 2.7000e-05
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.7210 - loss: 0.8108 - val_accuracy: 0.7401 - val_loss: 0.8002 - learning_rate: 8.1000e-06
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 246ms/step - accuracy: 0.7475 - loss: 0.7311 - val_accuracy: 0.7316 - val_loss: 0.7864 - learning_rate: 8.1000e-06
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 271ms/step - accuracy: 0.7081 - loss: 0.8155 - val_accuracy: 0.7401 - val_loss: 0.7800 - learning_rate: 8.1000e-06
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 244ms/step - accuracy: 0.7363 - loss: 0.7698 - val_accuracy: 0.7373 - val_loss: 0.7835 - learning_rate: 8.1000e-06
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 243ms/step - accuracy: 0.7191 - loss: 0.8271 - val_accuracy: 0.7401 - val_loss: 0.7809 - learning_rate: 8.1000e-06
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 244ms/step - accuracy: 0.7447 - loss: 0.7154 - val_accuracy: 0.7345 - val_loss: 0.7820 - learning_rate: 8.1000e-06
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 244ms/step - accuracy: 0.7365 - loss: 0.7717 - val_accuracy: 0.7373 - val_loss: 0.7807 - learning_rate: 2.4300e-06
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.7489 - loss: 0.7536 - val_accuracy: 0.7345 - val_loss: 0.7812 - learning_rate: 2.4300e-06
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 245ms/step - accuracy: 0.7356 - loss: 0.7841 - val_accuracy: 0.7401 - val_loss: 0.7801 - learning_rate: 2.4300e-06
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.7337 - loss: 0.7866 - val_accuracy: 0.7401 - val_loss: 0.7802 - learning_rate: 7.2900e-07
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7677 - loss: 0.7064
# Test accuracy: 0.7394958138465881

# %% [markdown]
# ####EfficientNetB3

# %%
data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.Lambda(preprocess_input),
])

base_model = EfficientNetB3(
    include_top=False,
    input_shape=(224,224,3),
    weights="imagenet"
)
base_model.trainable = False

model_b3 = tf.keras.Sequential([
    data_augment,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(10, activation="softmax")
])

model_b3.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


callbacks = [
    ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, verbose=1),
    EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True, verbose=1),
    ModelCheckpoint("best_efficientnetb3.keras", save_best_only=True, verbose=1)
]

history = model_b3.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=callbacks,
    verbose=1
)

base_model.trainable = True
for layer in base_model.layers[:-100]:
    layer.trainable = False

model_b3.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history_ft = model_b3.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=callbacks,
    verbose=1
)

test_loss, test_acc = model_b3.evaluate(test_ds)
print("Test accuracy:", test_acc)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2963 - loss: 2.5177
# Epoch 1: val_loss improved from inf to 1.55125, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 397s 6s/step - accuracy: 0.2981 - loss: 2.5091 - val_accuracy: 0.4689 - val_loss: 1.5513 - learning_rate: 0.0010
# Epoch 2/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5981 - loss: 1.2275
# Epoch 2: val_loss improved from 1.55125 to 1.04037, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 190ms/step - accuracy: 0.5987 - loss: 1.2274 - val_accuracy: 0.7316 - val_loss: 1.0404 - learning_rate: 0.0010
# Epoch 3/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6830 - loss: 1.0376
# Epoch 3: val_loss improved from 1.04037 to 0.87559, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.6828 - loss: 1.0367 - val_accuracy: 0.7458 - val_loss: 0.8756 - learning_rate: 0.0010
# Epoch 4/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6812 - loss: 0.9964
# Epoch 4: val_loss improved from 0.87559 to 0.83342, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.6818 - loss: 0.9948 - val_accuracy: 0.7316 - val_loss: 0.8334 - learning_rate: 0.0010
# Epoch 5/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7538 - loss: 0.8121
# Epoch 5: val_loss improved from 0.83342 to 0.75158, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.7534 - loss: 0.8122 - val_accuracy: 0.7655 - val_loss: 0.7516 - learning_rate: 0.0010
# Epoch 6/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7748 - loss: 0.7759
# Epoch 6: val_loss improved from 0.75158 to 0.72687, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 191ms/step - accuracy: 0.7746 - loss: 0.7756 - val_accuracy: 0.7768 - val_loss: 0.7269 - learning_rate: 0.0010
# Epoch 7/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7940 - loss: 0.6700
# Epoch 7: val_loss did not improve from 0.72687
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.7937 - loss: 0.6711 - val_accuracy: 0.7853 - val_loss: 0.7448 - learning_rate: 0.0010
# Epoch 8/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7943 - loss: 0.7111
# Epoch 8: val_loss did not improve from 0.72687
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.7941 - loss: 0.7114 - val_accuracy: 0.7486 - val_loss: 0.7745 - learning_rate: 0.0010
# Epoch 9/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7784 - loss: 0.6667
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 9: val_loss did not improve from 0.72687
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.7790 - loss: 0.6664 - val_accuracy: 0.7627 - val_loss: 0.7635 - learning_rate: 0.0010
# Epoch 10/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8269 - loss: 0.5785
# Epoch 10: val_loss improved from 0.72687 to 0.71972, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 199ms/step - accuracy: 0.8264 - loss: 0.5796 - val_accuracy: 0.7712 - val_loss: 0.7197 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 10.
# Epoch 1/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.6491 - loss: 1.1048
# Epoch 1: val_loss did not improve from 0.71972
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 45s 295ms/step - accuracy: 0.6498 - loss: 1.1033 - val_accuracy: 0.7966 - val_loss: 0.7729 - learning_rate: 1.0000e-04
# Epoch 2/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.7699 - loss: 0.7339
# Epoch 2: val_loss did not improve from 0.71972
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 234ms/step - accuracy: 0.7700 - loss: 0.7334 - val_accuracy: 0.7938 - val_loss: 0.7711 - learning_rate: 1.0000e-04
# Epoch 3/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8222 - loss: 0.5683
# Epoch 3: val_loss did not improve from 0.71972
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - accuracy: 0.8222 - loss: 0.5686 - val_accuracy: 0.8023 - val_loss: 0.7422 - learning_rate: 1.0000e-04
# Epoch 4/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8540 - loss: 0.5011
# Epoch 4: val_loss improved from 0.71972 to 0.69351, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 250ms/step - accuracy: 0.8541 - loss: 0.5006 - val_accuracy: 0.8220 - val_loss: 0.6935 - learning_rate: 1.0000e-04
# Epoch 5/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8731 - loss: 0.4533
# Epoch 5: val_loss improved from 0.69351 to 0.67300, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 254ms/step - accuracy: 0.8734 - loss: 0.4528 - val_accuracy: 0.8192 - val_loss: 0.6730 - learning_rate: 1.0000e-04
# Epoch 6/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9056 - loss: 0.3788
# Epoch 6: val_loss improved from 0.67300 to 0.66144, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 250ms/step - accuracy: 0.9055 - loss: 0.3788 - val_accuracy: 0.8164 - val_loss: 0.6614 - learning_rate: 1.0000e-04
# Epoch 7/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9195 - loss: 0.3510
# Epoch 7: val_loss did not improve from 0.66144
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9194 - loss: 0.3510 - val_accuracy: 0.8023 - val_loss: 0.6804 - learning_rate: 1.0000e-04
# Epoch 8/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9390 - loss: 0.2803
# Epoch 8: val_loss improved from 0.66144 to 0.64193, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 255ms/step - accuracy: 0.9387 - loss: 0.2809 - val_accuracy: 0.8136 - val_loss: 0.6419 - learning_rate: 1.0000e-04
# Epoch 9/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9328 - loss: 0.2838
# Epoch 9: val_loss improved from 0.64193 to 0.62924, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 256ms/step - accuracy: 0.9330 - loss: 0.2837 - val_accuracy: 0.8220 - val_loss: 0.6292 - learning_rate: 1.0000e-04
# Epoch 10/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9331 - loss: 0.2800
# Epoch 10: val_loss did not improve from 0.62924
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 226ms/step - accuracy: 0.9331 - loss: 0.2803 - val_accuracy: 0.8277 - val_loss: 0.6352 - learning_rate: 1.0000e-04
# Epoch 11/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9432 - loss: 0.2618
# Epoch 11: val_loss did not improve from 0.62924
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 226ms/step - accuracy: 0.9431 - loss: 0.2623 - val_accuracy: 0.8192 - val_loss: 0.6499 - learning_rate: 1.0000e-04
# Epoch 12/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9417 - loss: 0.2498
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 12: val_loss did not improve from 0.62924
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 230ms/step - accuracy: 0.9418 - loss: 0.2499 - val_accuracy: 0.8305 - val_loss: 0.6634 - learning_rate: 1.0000e-04
# Epoch 13/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9628 - loss: 0.2070
# Epoch 13: val_loss did not improve from 0.62924
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9626 - loss: 0.2074 - val_accuracy: 0.8305 - val_loss: 0.6542 - learning_rate: 3.0000e-05
# Epoch 14/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9594 - loss: 0.2075
# Epoch 14: val_loss did not improve from 0.62924
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 227ms/step - accuracy: 0.9595 - loss: 0.2076 - val_accuracy: 0.8362 - val_loss: 0.6496 - learning_rate: 3.0000e-05
# Epoch 15/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9595 - loss: 0.2256
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 15: val_loss did not improve from 0.62924
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.9595 - loss: 0.2254 - val_accuracy: 0.8305 - val_loss: 0.6464 - learning_rate: 3.0000e-05
# Epoch 16/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9657 - loss: 0.2061
# Epoch 16: val_loss did not improve from 0.62924
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 228ms/step - accuracy: 0.9657 - loss: 0.2061 - val_accuracy: 0.8249 - val_loss: 0.6463 - learning_rate: 9.0000e-06
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 21s 5s/step - accuracy: 0.8881 - loss: 0.4194
# Test accuracy: 0.8739495873451233

# %%
model_b3.save("/content/drive/MyDrive/mashrooms-vision/model-b3-100.keras")

# %% [markdown]
# ####ResNet

# %%
data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

base_model = ResNet50(
    include_top=False,
    input_shape=(224,224,3),
    weights="imagenet"
)

base_model.trainable = True
for layer in base_model.layers[:-100]:
    layer.trainable = False

inputs = tf.keras.Input(shape=(224,224,3))
x = data_augment(inputs)
x = tf.keras.applications.resnet.preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(10, activation="softmax")(x)

model_resnet = tf.keras.Model(inputs, outputs, name="ResNet50-Mushroom")


model_resnet.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, verbose=1)
early_stop = EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True, verbose=1)
checkpoint = ModelCheckpoint("best_resnet.keras", save_best_only=True, verbose=1)

callbacks = [reduce_lr, early_stop, checkpoint]

history = model_resnet.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks,
    verbose=1
)

test_loss, test_acc = model_resnet.evaluate(test_ds)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.1783 - loss: 2.9781
# Epoch 1: val_loss improved from inf to 1.42685, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 53s 450ms/step - accuracy: 0.1796 - loss: 2.9716 - val_accuracy: 0.5565 - val_loss: 1.4269 - learning_rate: 1.0000e-04
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.4623 - loss: 1.6864
# Epoch 2: val_loss improved from 1.42685 to 0.91639, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 25s 409ms/step - accuracy: 0.4634 - loss: 1.6838 - val_accuracy: 0.7175 - val_loss: 0.9164 - learning_rate: 1.0000e-04
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.6309 - loss: 1.1664
# Epoch 3: val_loss improved from 0.91639 to 0.83825, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 25s 407ms/step - accuracy: 0.6312 - loss: 1.1657 - val_accuracy: 0.7655 - val_loss: 0.8382 - learning_rate: 1.0000e-04
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.7159 - loss: 0.9137
# Epoch 4: val_loss did not improve from 0.83825
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 324ms/step - accuracy: 0.7158 - loss: 0.9142 - val_accuracy: 0.7486 - val_loss: 0.8471 - learning_rate: 1.0000e-04
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.7573 - loss: 0.8581
# Epoch 5: val_loss improved from 0.83825 to 0.72091, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 25s 410ms/step - accuracy: 0.7572 - loss: 0.8581 - val_accuracy: 0.7966 - val_loss: 0.7209 - learning_rate: 1.0000e-04
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.7870 - loss: 0.7184
# Epoch 6: val_loss improved from 0.72091 to 0.67848, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 29s 468ms/step - accuracy: 0.7873 - loss: 0.7178 - val_accuracy: 0.8023 - val_loss: 0.6785 - learning_rate: 1.0000e-04
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.8474 - loss: 0.5562
# Epoch 7: val_loss improved from 0.67848 to 0.64121, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 24s 395ms/step - accuracy: 0.8473 - loss: 0.5566 - val_accuracy: 0.8164 - val_loss: 0.6412 - learning_rate: 1.0000e-04
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.8468 - loss: 0.5200
# Epoch 8: val_loss did not improve from 0.64121
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 323ms/step - accuracy: 0.8468 - loss: 0.5201 - val_accuracy: 0.8277 - val_loss: 0.6625 - learning_rate: 1.0000e-04
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.8578 - loss: 0.5140
# Epoch 9: val_loss improved from 0.64121 to 0.60990, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 24s 400ms/step - accuracy: 0.8578 - loss: 0.5137 - val_accuracy: 0.8390 - val_loss: 0.6099 - learning_rate: 1.0000e-04
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9084 - loss: 0.3668
# Epoch 10: val_loss did not improve from 0.60990
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 340ms/step - accuracy: 0.9081 - loss: 0.3677 - val_accuracy: 0.8390 - val_loss: 0.6889 - learning_rate: 1.0000e-04
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9091 - loss: 0.4002
# Epoch 11: val_loss did not improve from 0.60990
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 320ms/step - accuracy: 0.9089 - loss: 0.4005 - val_accuracy: 0.8220 - val_loss: 0.7557 - learning_rate: 1.0000e-04
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9096 - loss: 0.3588
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 12: val_loss did not improve from 0.60990
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 326ms/step - accuracy: 0.9095 - loss: 0.3593 - val_accuracy: 0.8164 - val_loss: 0.7085 - learning_rate: 1.0000e-04
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9129 - loss: 0.3331
# Epoch 13: val_loss did not improve from 0.60990
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 320ms/step - accuracy: 0.9129 - loss: 0.3331 - val_accuracy: 0.8418 - val_loss: 0.6378 - learning_rate: 3.0000e-05
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9248 - loss: 0.2982
# Epoch 14: val_loss did not improve from 0.60990
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 338ms/step - accuracy: 0.9249 - loss: 0.2980 - val_accuracy: 0.8559 - val_loss: 0.6190 - learning_rate: 3.0000e-05
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9264 - loss: 0.3208
# Epoch 15: val_loss improved from 0.60990 to 0.60574, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 24s 399ms/step - accuracy: 0.9265 - loss: 0.3206 - val_accuracy: 0.8362 - val_loss: 0.6057 - learning_rate: 3.0000e-05
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9251 - loss: 0.3058
# Epoch 16: val_loss improved from 0.60574 to 0.59799, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 25s 402ms/step - accuracy: 0.9252 - loss: 0.3055 - val_accuracy: 0.8446 - val_loss: 0.5980 - learning_rate: 3.0000e-05
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9247 - loss: 0.2855
# Epoch 17: val_loss improved from 0.59799 to 0.59221, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 25s 413ms/step - accuracy: 0.9248 - loss: 0.2855 - val_accuracy: 0.8418 - val_loss: 0.5922 - learning_rate: 3.0000e-05
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9452 - loss: 0.2430
# Epoch 18: val_loss did not improve from 0.59221
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 324ms/step - accuracy: 0.9451 - loss: 0.2433 - val_accuracy: 0.8390 - val_loss: 0.5964 - learning_rate: 3.0000e-05
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9552 - loss: 0.2268
# Epoch 19: val_loss improved from 0.59221 to 0.59219, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 455ms/step - accuracy: 0.9552 - loss: 0.2269 - val_accuracy: 0.8531 - val_loss: 0.5922 - learning_rate: 3.0000e-05
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9501 - loss: 0.2330
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 20: val_loss did not improve from 0.59219
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 319ms/step - accuracy: 0.9500 - loss: 0.2333 - val_accuracy: 0.8418 - val_loss: 0.6018 - learning_rate: 3.0000e-05
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9607 - loss: 0.2252
# Epoch 21: val_loss improved from 0.59219 to 0.58707, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 24s 382ms/step - accuracy: 0.9605 - loss: 0.2254 - val_accuracy: 0.8418 - val_loss: 0.5871 - learning_rate: 9.0000e-06
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9530 - loss: 0.2264
# Epoch 22: val_loss improved from 0.58707 to 0.58436, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 358ms/step - accuracy: 0.9529 - loss: 0.2265 - val_accuracy: 0.8503 - val_loss: 0.5844 - learning_rate: 9.0000e-06
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9482 - loss: 0.2178
# Epoch 23: val_loss improved from 0.58436 to 0.58287, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 445ms/step - accuracy: 0.9482 - loss: 0.2182 - val_accuracy: 0.8418 - val_loss: 0.5829 - learning_rate: 9.0000e-06
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9517 - loss: 0.2302
# Epoch 24: val_loss did not improve from 0.58287
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 319ms/step - accuracy: 0.9517 - loss: 0.2303 - val_accuracy: 0.8390 - val_loss: 0.5860 - learning_rate: 9.0000e-06
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9566 - loss: 0.2218
# Epoch 25: val_loss did not improve from 0.58287
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 325ms/step - accuracy: 0.9566 - loss: 0.2218 - val_accuracy: 0.8475 - val_loss: 0.5867 - learning_rate: 9.0000e-06
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9661 - loss: 0.2092
# Epoch 26: val_loss improved from 0.58287 to 0.58168, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 366ms/step - accuracy: 0.9660 - loss: 0.2093 - val_accuracy: 0.8531 - val_loss: 0.5817 - learning_rate: 9.0000e-06
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9700 - loss: 0.1914
# Epoch 27: val_loss did not improve from 0.58168
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 320ms/step - accuracy: 0.9699 - loss: 0.1915 - val_accuracy: 0.8475 - val_loss: 0.5829 - learning_rate: 9.0000e-06
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9581 - loss: 0.2217
# Epoch 28: val_loss did not improve from 0.58168
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 320ms/step - accuracy: 0.9581 - loss: 0.2214 - val_accuracy: 0.8418 - val_loss: 0.5867 - learning_rate: 9.0000e-06
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9662 - loss: 0.2091
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
#
# Epoch 29: val_loss did not improve from 0.58168
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 325ms/step - accuracy: 0.9662 - loss: 0.2089 - val_accuracy: 0.8418 - val_loss: 0.5840 - learning_rate: 9.0000e-06
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9673 - loss: 0.1972
# Epoch 30: val_loss did not improve from 0.58168
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 319ms/step - accuracy: 0.9673 - loss: 0.1973 - val_accuracy: 0.8446 - val_loss: 0.5866 - learning_rate: 2.7000e-06
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9619 - loss: 0.1920
# Epoch 31: val_loss did not improve from 0.58168
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.9619 - loss: 0.1921 - val_accuracy: 0.8446 - val_loss: 0.5842 - learning_rate: 2.7000e-06
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9687 - loss: 0.1857
# Epoch 32: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
#
# Epoch 32: val_loss did not improve from 0.58168
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 321ms/step - accuracy: 0.9686 - loss: 0.1858 - val_accuracy: 0.8475 - val_loss: 0.5821 - learning_rate: 2.7000e-06
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9616 - loss: 0.1917
# Epoch 33: val_loss improved from 0.58168 to 0.58158, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 24s 404ms/step - accuracy: 0.9616 - loss: 0.1918 - val_accuracy: 0.8418 - val_loss: 0.5816 - learning_rate: 8.1000e-07
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9610 - loss: 0.1955
# Epoch 34: val_loss did not improve from 0.58158
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 36s 319ms/step - accuracy: 0.9610 - loss: 0.1954 - val_accuracy: 0.8446 - val_loss: 0.5844 - learning_rate: 8.1000e-07
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9630 - loss: 0.2126
# Epoch 35: val_loss did not improve from 0.58158
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 328ms/step - accuracy: 0.9630 - loss: 0.2124 - val_accuracy: 0.8475 - val_loss: 0.5845 - learning_rate: 8.1000e-07
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9698 - loss: 0.1821
# Epoch 36: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
#
# Epoch 36: val_loss did not improve from 0.58158
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 324ms/step - accuracy: 0.9697 - loss: 0.1822 - val_accuracy: 0.8475 - val_loss: 0.5843 - learning_rate: 8.1000e-07
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9660 - loss: 0.1933
# Epoch 37: val_loss did not improve from 0.58158
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 320ms/step - accuracy: 0.9660 - loss: 0.1932 - val_accuracy: 0.8446 - val_loss: 0.5857 - learning_rate: 2.4300e-07
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9731 - loss: 0.1753
# Epoch 38: val_loss did not improve from 0.58158
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 324ms/step - accuracy: 0.9729 - loss: 0.1757 - val_accuracy: 0.8418 - val_loss: 0.5851 - learning_rate: 2.4300e-07
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9674 - loss: 0.1854
# Epoch 39: ReduceLROnPlateau reducing learning rate to 7.289999643944612e-08.
#
# Epoch 39: val_loss did not improve from 0.58158
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 319ms/step - accuracy: 0.9674 - loss: 0.1854 - val_accuracy: 0.8418 - val_loss: 0.5842 - learning_rate: 2.4300e-07
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9643 - loss: 0.1897
# Epoch 40: val_loss did not improve from 0.58158
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 326ms/step - accuracy: 0.9642 - loss: 0.1899 - val_accuracy: 0.8475 - val_loss: 0.5859 - learning_rate: 7.2900e-08
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 33.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.8715 - loss: 0.4939
# Test accuracy: 0.8739495873451233

# %%
model_resnet.save("/content/drive/MyDrive/mashrooms-vision/model-res.keras")
