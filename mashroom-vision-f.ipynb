# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import cv2
import os

import matplotlib.pyplot as plt
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
import albumentations as A
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB3, EfficientNetB0, ResNet50
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.layers import Rescaling
from tensorflow.keras.regularizers import l2
#from pyngrok import ngrok

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATASET_DIR = "/content/drive/MyDrive/mashrooms-vision/"
IMG_DIR = DATASET_DIR + "dataset/dataset/"

app_path = DATASET_DIR + "app.py"
train_df = pd.read_csv(DATASET_DIR + "train.csv")
test_df = pd.read_csv(DATASET_DIR + "test.csv")

# %%
train_df.head()
# Out:
#    Image  Mushroom
# 0      1         0
# 1      2         0
# 2      3         0
# 3      4         0
# 4      5         0

# %%
train_df.shape
# Out:
# (2365, 2)

# %%
class_counts = train_df['Mushroom'].value_counts()

plt.figure(figsize=(8,5))
plt.bar(class_counts.index.astype(str), class_counts.values)

plt.xlabel("Class")
plt.ylabel("Amout")
plt.xticks(rotation=0)
plt.show()

# %%
classes = train_df['Mushroom'].unique()

plt.figure(figsize=(12, 6))

for i, cls in enumerate(classes):
    sample = train_df[train_df['Mushroom'] == cls].iloc[4]
    img_name = f"{sample['Image']:05d}.jpg"

    img_path = os.path.join(IMG_DIR, img_name)

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.subplot(1, len(classes), i + 1)
    plt.imshow(img)
    plt.title(f"Class: {cls}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
bad = []
for file in os.listdir(IMG_DIR):
    img = cv2.imread(os.path.join(IMG_DIR, file))
    if img is None:
        bad.append(file)
bad
# Out:
# []

# %% [markdown]
# ##Data splitting for model training

# %%
train_unsampled, val = train_test_split(train_df, stratify=train_df['Mushroom'], test_size=0.2, random_state=42)
val, test = train_test_split(val, stratify=val['Mushroom'], test_size=0.25, random_state=42)

# %%
def pathify(df):
    df['Image'] = df['Image'].apply(lambda x: IMG_DIR + str(x).zfill(5) + ".jpg")
    return df

train_unsampled = pathify(train_unsampled)
val = pathify(val)
test = pathify(test)

# %%
train_unsampled
# Out:
#                                                   Image  Mushroom
# 370   /content/drive/MyDrive/mashrooms-vision/datase...         1
# 134   /content/drive/MyDrive/mashrooms-vision/datase...         0
# 904   /content/drive/MyDrive/mashrooms-vision/datase...         3
# 380   /content/drive/MyDrive/mashrooms-vision/datase...         1
# 2230  /content/drive/MyDrive/mashrooms-vision/datase...         9
# ...                                                 ...       ...
# 1351  /content/drive/MyDrive/mashrooms-vision/datase...         5
# 1004  /content/drive/MyDrive/mashrooms-vision/datase...         4
# 223   /content/drive/MyDrive/mashrooms-vision/datase...         0
# 886   /content/drive/MyDrive/mashrooms-vision/datase...         3
# 759   /content/drive/MyDrive/mashrooms-vision/datase...         3
#
# [1892 rows x 2 columns]

# %%
train_unsampled['Mushroom'].unique()
# Out:
# array([1, 0, 3, 9, 7, 2, 5, 8, 6, 4])

# %%
train_unsampled['Mushroom'].value_counts()
# Out:
# Mushroom
# 1    192
# 9    192
# 8    192
# 7    192
# 2    192
# 5    192
# 0    190
# 6    190
# 4    182
# 3    178
# Name: count, dtype: int64

# %% [markdown]
# ##Dataset preparation

# %%
BATCH_SIZE = 32
IMAGE_SIZE = (224,224)

# %%
def load_image(image_path, label):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, IMAGE_SIZE)
    #image = image / 255.0 #only for b0
    return image, label

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_unsampled['Image'].values, train_unsampled['Mushroom'].values))
train_ds = train_ds.shuffle(len(train_unsampled)).map(load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val['Image'].values, val['Mushroom'].values))
val_ds = val_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((test['Image'].values, test['Mushroom'].values))
test_ds = test_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ##Dataset inspection and sanity check

# %%
for x, y in train_ds.take(1):
    print("Batch images:", x.shape)
    print("Batch labels:", y.numpy())
# Out:
# Batch images: (32, 224, 224, 3)
# Batch labels: [3 7 5 1 0 4 5 5 1 3 2 8 2 1 5 3 1 7 7 2 5 8 6 5 0 3 1 0 3 6 7 9]

# %%
num_classes = train_unsampled['Mushroom'].nunique()
print("Number of classes:", num_classes)

print("Train classes:", train_unsampled['Mushroom'].unique())
print("Val classes:", val['Mushroom'].unique())
print("Test classes:", test['Mushroom'].unique())

print("Train distribution:\n", train_unsampled['Mushroom'].value_counts())
print("Val distribution:\n", val['Mushroom'].value_counts())
print("Test distribution:\n", test['Mushroom'].value_counts())
# Out:
# Number of classes: 10
# Train classes: [1 0 3 9 7 2 5 8 6 4]
# Val classes: [5 2 1 9 0 8 7 6 3 4]
# Test classes: [6 2 8 5 9 4 7 3 0 1]
# Train distribution:
#  Mushroom
# 1    192
# 9    192
# 8    192
# 7    192
# 2    192
# 5    192
# 0    190
# 6    190
# 4    182
# 3    178
# Name: count, dtype: int64
# Val distribution:
#  Mushroom
# 5    36
# 2    36
# 1    36
# 9    36
# 0    36
# 8    36
# 7    36
# 6    36
# 3    33
# 4    33
# Name: count, dtype: int64
# Test distribution:
#  Mushroom
# 6    12
# 2    12
# 8    12
# 5    12
# 9    12
# 4    12
# 7    12
# 0    12
# 1    12
# 3    11
# Name: count, dtype: int64

# %% [markdown]
# ##CNN models
# ####EfficientNetB0

# %%
for image, label in train_ds.take(1):
    sample_image = image[0]
    break

data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
])

augmented_images = [data_augment(tf.expand_dims(sample_image, 0)) for _ in range(7)]

plt.figure(figsize=(12,6))

plt.subplot(2,4,1)
plt.imshow(sample_image.numpy().astype("uint8"))
plt.title("Original")
plt.axis("off")

for i, img in enumerate(augmented_images):
    plt.subplot(2,4,i+2)
    plt.imshow(img[0].numpy().astype("uint8"))
    plt.title(f"Aug {i+1}")
    plt.axis("off")

plt.show()

# %%
def plot_training_history(history, model_name="Model"):
    acc = history.history.get("accuracy")
    val_acc = history.history.get("val_accuracy")
    loss = history.history.get("loss")
    val_loss = history.history.get("val_loss")

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, label="Train Accuracy")
    plt.plot(epochs, val_acc, label="Validation Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.title(f"{model_name} – Accuracy")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, label="Train Loss")
    plt.plot(epochs, val_loss, label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title(f"{model_name} – Loss")
    plt.legend()
    plt.grid(True)

# %%
data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
])

base_model_b0 = tf.keras.applications.EfficientNetB0(
    include_top=False,
    input_shape=(224,224,3),
    weights="imagenet"
)


base_model_b0.trainable = True
for layer in base_model_b0.layers[:40]:
    layer.trainable = False

model = tf.keras.Sequential([
    layers.Lambda(preprocess_input),
    data_augment,
    base_model_b0,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(10, activation="softmax")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(3e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3),
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True)
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks
)

test_loss, test_acc = model.evaluate(test_ds)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 51s 286ms/step - accuracy: 0.1600 - loss: 2.9812 - val_accuracy: 0.4492 - val_loss: 1.8647 - learning_rate: 3.0000e-04
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.4363 - loss: 1.7275 - val_accuracy: 0.6412 - val_loss: 1.2392 - learning_rate: 3.0000e-04
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.5906 - loss: 1.2871 - val_accuracy: 0.7542 - val_loss: 0.8499 - learning_rate: 3.0000e-04
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.6856 - loss: 0.9544 - val_accuracy: 0.7938 - val_loss: 0.6973 - learning_rate: 3.0000e-04
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 245ms/step - accuracy: 0.7241 - loss: 0.8524 - val_accuracy: 0.8023 - val_loss: 0.6587 - learning_rate: 3.0000e-04
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.7518 - loss: 0.7526 - val_accuracy: 0.8164 - val_loss: 0.6213 - learning_rate: 3.0000e-04
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 243ms/step - accuracy: 0.7889 - loss: 0.6561 - val_accuracy: 0.8220 - val_loss: 0.6164 - learning_rate: 3.0000e-04
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.7961 - loss: 0.6138 - val_accuracy: 0.8249 - val_loss: 0.6243 - learning_rate: 3.0000e-04
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8291 - loss: 0.4995 - val_accuracy: 0.8418 - val_loss: 0.5654 - learning_rate: 3.0000e-04
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8506 - loss: 0.4942 - val_accuracy: 0.8503 - val_loss: 0.5332 - learning_rate: 3.0000e-04
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 244ms/step - accuracy: 0.8609 - loss: 0.4080 - val_accuracy: 0.8446 - val_loss: 0.5275 - learning_rate: 3.0000e-04
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8870 - loss: 0.3430 - val_accuracy: 0.8559 - val_loss: 0.4982 - learning_rate: 3.0000e-04
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8874 - loss: 0.3351 - val_accuracy: 0.8362 - val_loss: 0.5577 - learning_rate: 3.0000e-04
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 265ms/step - accuracy: 0.8881 - loss: 0.3331 - val_accuracy: 0.8333 - val_loss: 0.5073 - learning_rate: 3.0000e-04
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 242ms/step - accuracy: 0.9210 - loss: 0.2646 - val_accuracy: 0.8475 - val_loss: 0.5394 - learning_rate: 3.0000e-04
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 241ms/step - accuracy: 0.9248 - loss: 0.2519 - val_accuracy: 0.8362 - val_loss: 0.5352 - learning_rate: 9.0000e-05
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 243ms/step - accuracy: 0.9285 - loss: 0.2190 - val_accuracy: 0.8390 - val_loss: 0.5380 - learning_rate: 9.0000e-05
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.9269 - loss: 0.2396 - val_accuracy: 0.8503 - val_loss: 0.5303 - learning_rate: 9.0000e-05
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 265ms/step - accuracy: 0.9364 - loss: 0.2051 - val_accuracy: 0.8475 - val_loss: 0.5244 - learning_rate: 2.7000e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9090 - loss: 0.3857
# Test accuracy: 0.8739495873451233
# Test loss: 0.44129297137260437

# %%
plot_training_history(history, model_name="EfficientNetB0")

# %%
model.save("/content/drive/MyDrive/mashrooms-vision/model-b0.keras")

# %% [markdown]
# ####EfficientNetB3

# %%
data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
])

base_model = EfficientNetB3(
    include_top=False,
    input_shape=(224,224,3),
    weights="imagenet"
)
base_model.trainable = False

model_b3 = tf.keras.Sequential([
    layers.Lambda(preprocess_input),
    data_augment,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(10, activation="softmax")
])

model_b3.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


callbacks = [
    ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, verbose=1),
    EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True, verbose=1),
    ModelCheckpoint("best_efficientnetb3.keras", save_best_only=True, verbose=1)
]

history = model_b3.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15,
    callbacks=callbacks,
)

base_model.trainable = True
for layer in base_model.layers[:-100]:
    layer.trainable = False

model_b3.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history_ft = model_b3.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=callbacks,
)

test_loss, test_acc = model_b3.evaluate(test_ds)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.2365 - loss: 2.5608
# Epoch 1: val_loss improved from inf to 1.72043, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 34s 284ms/step - accuracy: 0.2400 - loss: 2.5465 - val_accuracy: 0.3814 - val_loss: 1.7204 - learning_rate: 0.0010
# Epoch 2/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5812 - loss: 1.3588
# Epoch 2: val_loss improved from 1.72043 to 1.17326, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.5814 - loss: 1.3578 - val_accuracy: 0.6356 - val_loss: 1.1733 - learning_rate: 0.0010
# Epoch 3/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6461 - loss: 1.1479
# Epoch 3: val_loss improved from 1.17326 to 1.00936, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 207ms/step - accuracy: 0.6460 - loss: 1.1484 - val_accuracy: 0.6780 - val_loss: 1.0094 - learning_rate: 0.0010
# Epoch 4/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6704 - loss: 1.0752
# Epoch 4: val_loss improved from 1.00936 to 0.88746, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 190ms/step - accuracy: 0.6703 - loss: 1.0751 - val_accuracy: 0.7090 - val_loss: 0.8875 - learning_rate: 0.0010
# Epoch 5/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.6675 - loss: 1.0505
# Epoch 5: val_loss improved from 0.88746 to 0.84935, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 13s 214ms/step - accuracy: 0.6681 - loss: 1.0489 - val_accuracy: 0.7232 - val_loss: 0.8494 - learning_rate: 0.0010
# Epoch 6/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7102 - loss: 0.9248
# Epoch 6: val_loss improved from 0.84935 to 0.80896, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 194ms/step - accuracy: 0.7100 - loss: 0.9256 - val_accuracy: 0.7429 - val_loss: 0.8090 - learning_rate: 0.0010
# Epoch 7/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7196 - loss: 0.8793
# Epoch 7: val_loss did not improve from 0.80896
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 183ms/step - accuracy: 0.7196 - loss: 0.8791 - val_accuracy: 0.7260 - val_loss: 0.8233 - learning_rate: 0.0010
# Epoch 8/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7616 - loss: 0.8002
# Epoch 8: val_loss improved from 0.80896 to 0.80250, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 202ms/step - accuracy: 0.7608 - loss: 0.8017 - val_accuracy: 0.7684 - val_loss: 0.8025 - learning_rate: 0.0010
# Epoch 9/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.7354 - loss: 0.8256
# Epoch 9: val_loss did not improve from 0.80250
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.7356 - loss: 0.8256 - val_accuracy: 0.7316 - val_loss: 0.8178 - learning_rate: 0.0010
# Epoch 10/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7694 - loss: 0.7686
# Epoch 10: val_loss improved from 0.80250 to 0.75262, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 192ms/step - accuracy: 0.7690 - loss: 0.7693 - val_accuracy: 0.7797 - val_loss: 0.7526 - learning_rate: 0.0010
# Epoch 11/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7461 - loss: 0.7825
# Epoch 11: val_loss did not improve from 0.75262
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.7461 - loss: 0.7827 - val_accuracy: 0.7712 - val_loss: 0.7637 - learning_rate: 0.0010
# Epoch 12/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7993 - loss: 0.6735
# Epoch 12: val_loss did not improve from 0.75262
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.7988 - loss: 0.6753 - val_accuracy: 0.7486 - val_loss: 0.8244 - learning_rate: 0.0010
# Epoch 13/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7938 - loss: 0.6677
# Epoch 13: val_loss improved from 0.75262 to 0.70921, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 201ms/step - accuracy: 0.7934 - loss: 0.6690 - val_accuracy: 0.7938 - val_loss: 0.7092 - learning_rate: 0.0010
# Epoch 14/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7890 - loss: 0.7304
# Epoch 14: val_loss improved from 0.70921 to 0.70156, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 191ms/step - accuracy: 0.7893 - loss: 0.7293 - val_accuracy: 0.7966 - val_loss: 0.7016 - learning_rate: 0.0010
# Epoch 15/15
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7813 - loss: 0.6992
# Epoch 15: val_loss did not improve from 0.70156
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - accuracy: 0.7817 - loss: 0.6990 - val_accuracy: 0.7825 - val_loss: 0.7762 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 14.
# Epoch 1/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.6593 - loss: 1.1163
# Epoch 1: val_loss did not improve from 0.70156
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 47s 301ms/step - accuracy: 0.6598 - loss: 1.1149 - val_accuracy: 0.7712 - val_loss: 0.7746 - learning_rate: 1.0000e-04
# Epoch 2/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.7465 - loss: 0.8111
# Epoch 2: val_loss did not improve from 0.70156
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 233ms/step - accuracy: 0.7466 - loss: 0.8106 - val_accuracy: 0.7825 - val_loss: 0.7682 - learning_rate: 1.0000e-04
# Epoch 3/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7977 - loss: 0.6641
# Epoch 3: val_loss did not improve from 0.70156
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.7976 - loss: 0.6641 - val_accuracy: 0.7768 - val_loss: 0.7846 - learning_rate: 1.0000e-04
# Epoch 4/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8425 - loss: 0.5820
# Epoch 4: val_loss did not improve from 0.70156
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 230ms/step - accuracy: 0.8422 - loss: 0.5822 - val_accuracy: 0.7881 - val_loss: 0.7575 - learning_rate: 1.0000e-04
# Epoch 5/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8219 - loss: 0.6199
# Epoch 5: val_loss did not improve from 0.70156
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.8221 - loss: 0.6192 - val_accuracy: 0.7910 - val_loss: 0.7520 - learning_rate: 1.0000e-04
# Epoch 6/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8446 - loss: 0.5473
# Epoch 6: val_loss did not improve from 0.70156
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.8448 - loss: 0.5469 - val_accuracy: 0.7966 - val_loss: 0.7138 - learning_rate: 1.0000e-04
# Epoch 7/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8672 - loss: 0.4661
# Epoch 7: val_loss did not improve from 0.70156
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 230ms/step - accuracy: 0.8674 - loss: 0.4658 - val_accuracy: 0.7938 - val_loss: 0.7060 - learning_rate: 1.0000e-04
# Epoch 8/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8959 - loss: 0.4169
# Epoch 8: val_loss did not improve from 0.70156
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 230ms/step - accuracy: 0.8959 - loss: 0.4170 - val_accuracy: 0.8051 - val_loss: 0.7020 - learning_rate: 1.0000e-04
# Epoch 9/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8766 - loss: 0.4295
# Epoch 9: val_loss improved from 0.70156 to 0.67420, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.8766 - loss: 0.4294 - val_accuracy: 0.8107 - val_loss: 0.6742 - learning_rate: 1.0000e-04
# Epoch 10/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8991 - loss: 0.3847
# Epoch 10: val_loss improved from 0.67420 to 0.66163, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 261ms/step - accuracy: 0.8995 - loss: 0.3841 - val_accuracy: 0.8136 - val_loss: 0.6616 - learning_rate: 1.0000e-04
# Epoch 11/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9035 - loss: 0.3654
# Epoch 11: val_loss improved from 0.66163 to 0.64505, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9034 - loss: 0.3656 - val_accuracy: 0.8164 - val_loss: 0.6450 - learning_rate: 1.0000e-04
# Epoch 12/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9276 - loss: 0.3277
# Epoch 12: val_loss did not improve from 0.64505
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 231ms/step - accuracy: 0.9275 - loss: 0.3277 - val_accuracy: 0.8192 - val_loss: 0.6742 - learning_rate: 1.0000e-04
# Epoch 13/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9263 - loss: 0.3181
# Epoch 13: val_loss improved from 0.64505 to 0.63360, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.9262 - loss: 0.3184 - val_accuracy: 0.8305 - val_loss: 0.6336 - learning_rate: 1.0000e-04
# Epoch 14/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9241 - loss: 0.3190
# Epoch 14: val_loss improved from 0.63360 to 0.63340, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.9243 - loss: 0.3186 - val_accuracy: 0.8362 - val_loss: 0.6334 - learning_rate: 1.0000e-04
# Epoch 15/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9352 - loss: 0.2812
# Epoch 15: val_loss did not improve from 0.63340
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 231ms/step - accuracy: 0.9352 - loss: 0.2812 - val_accuracy: 0.8390 - val_loss: 0.6419 - learning_rate: 1.0000e-04
# Epoch 16/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9446 - loss: 0.2636
# Epoch 16: val_loss did not improve from 0.63340
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.9445 - loss: 0.2640 - val_accuracy: 0.8390 - val_loss: 0.6448 - learning_rate: 1.0000e-04
# Epoch 17/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9285 - loss: 0.2864
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 17: val_loss did not improve from 0.63340
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 227ms/step - accuracy: 0.9286 - loss: 0.2862 - val_accuracy: 0.8305 - val_loss: 0.6610 - learning_rate: 1.0000e-04
# Epoch 18/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9416 - loss: 0.2578
# Epoch 18: val_loss did not improve from 0.63340
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.9416 - loss: 0.2578 - val_accuracy: 0.8362 - val_loss: 0.6474 - learning_rate: 3.0000e-05
# Epoch 19/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9507 - loss: 0.2561
# Epoch 19: val_loss did not improve from 0.63340
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 242ms/step - accuracy: 0.9507 - loss: 0.2560 - val_accuracy: 0.8305 - val_loss: 0.6469 - learning_rate: 3.0000e-05
# Epoch 20/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9474 - loss: 0.2409
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 20: val_loss did not improve from 0.63340
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.9474 - loss: 0.2411 - val_accuracy: 0.8305 - val_loss: 0.6429 - learning_rate: 3.0000e-05
# Epoch 21/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9508 - loss: 0.2580
# Epoch 21: val_loss did not improve from 0.63340
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9509 - loss: 0.2577 - val_accuracy: 0.8305 - val_loss: 0.6385 - learning_rate: 9.0000e-06
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.9149 - loss: 0.4046
# Test accuracy: 0.8991596698760986
# Test loss: 0.47926926612854004

# %%
model_b3.save("/content/drive/MyDrive/mashrooms-vision/model-b3-100.keras")

# %%
plot_training_history(history, model_name="EfficientNetB3")

# %% [markdown]
# ####ResNet

# %%
data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
], name="data_augmentation")


base_model = ResNet50(
    include_top=False,
    input_shape=(224, 224, 3),
    weights="imagenet"
)

base_model.trainable = True
for layer in base_model.layers[:-120]:
    layer.trainable = False

inputs = tf.keras.Input(shape=(224, 224, 3))

x = data_augment(inputs)
x = tf.keras.applications.resnet.preprocess_input(x)

x = base_model(x, training=False)

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(
    256,
    activation="relu",
    kernel_regularizer=l2(1e-4)
)(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(
    128,
    activation="relu",
    kernel_regularizer=l2(1e-4)
)(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(10, activation="softmax")(x)

model_resnet = tf.keras.Model(
    inputs,
    outputs,
    name="ResNet50_Mushroom_Classifier"
)

model_resnet.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


callbacks = [
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.3,
        patience=3,
        verbose=1
    ),
    EarlyStopping(
        monitor="val_loss",
        patience=7,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        "best_resnet50_mushrooms.keras",
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )
]

history = model_resnet.fit(
    train_ds,
    validation_data=val_ds,
    epochs=40,
    callbacks=callbacks,
    verbose=1
)


test_loss, test_acc = model_resnet.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.1612 - loss: 2.9593
# Epoch 1: val_loss improved from inf to 1.61807, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 58s 451ms/step - accuracy: 0.1624 - loss: 2.9537 - val_accuracy: 0.4746 - val_loss: 1.6181 - learning_rate: 1.0000e-04
# Epoch 2/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.4815 - loss: 1.6675
# Epoch 2: val_loss improved from 1.61807 to 1.23251, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 25s 401ms/step - accuracy: 0.4819 - loss: 1.6658 - val_accuracy: 0.6469 - val_loss: 1.2325 - learning_rate: 1.0000e-04
# Epoch 3/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5835 - loss: 1.3761
# Epoch 3: val_loss improved from 1.23251 to 0.91093, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 28s 467ms/step - accuracy: 0.5840 - loss: 1.3747 - val_accuracy: 0.7316 - val_loss: 0.9109 - learning_rate: 1.0000e-04
# Epoch 4/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.6836 - loss: 1.0705
# Epoch 4: val_loss improved from 0.91093 to 0.88024, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 24s 397ms/step - accuracy: 0.6835 - loss: 1.0706 - val_accuracy: 0.7401 - val_loss: 0.8802 - learning_rate: 1.0000e-04
# Epoch 5/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.7381 - loss: 0.8866
# Epoch 5: val_loss improved from 0.88024 to 0.80027, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 454ms/step - accuracy: 0.7379 - loss: 0.8870 - val_accuracy: 0.7712 - val_loss: 0.8003 - learning_rate: 1.0000e-04
# Epoch 6/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.7774 - loss: 0.7908
# Epoch 6: val_loss improved from 0.80027 to 0.72682, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 24s 401ms/step - accuracy: 0.7772 - loss: 0.7909 - val_accuracy: 0.7881 - val_loss: 0.7268 - learning_rate: 1.0000e-04
# Epoch 7/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.7891 - loss: 0.7117
# Epoch 7: val_loss improved from 0.72682 to 0.65661, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 450ms/step - accuracy: 0.7892 - loss: 0.7114 - val_accuracy: 0.8136 - val_loss: 0.6566 - learning_rate: 1.0000e-04
# Epoch 8/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8000 - loss: 0.6643
# Epoch 8: val_loss did not improve from 0.65661
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 365ms/step - accuracy: 0.8002 - loss: 0.6641 - val_accuracy: 0.8164 - val_loss: 0.6766 - learning_rate: 1.0000e-04
# Epoch 9/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8372 - loss: 0.5777
# Epoch 9: val_loss did not improve from 0.65661
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 363ms/step - accuracy: 0.8372 - loss: 0.5779 - val_accuracy: 0.7938 - val_loss: 0.7272 - learning_rate: 1.0000e-04
# Epoch 10/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8680 - loss: 0.4857
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 10: val_loss did not improve from 0.65661
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 363ms/step - accuracy: 0.8678 - loss: 0.4860 - val_accuracy: 0.7938 - val_loss: 0.7351 - learning_rate: 1.0000e-04
# Epoch 11/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.8832 - loss: 0.4436
# Epoch 11: val_loss improved from 0.65661 to 0.64693, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 30s 500ms/step - accuracy: 0.8833 - loss: 0.4436 - val_accuracy: 0.8220 - val_loss: 0.6469 - learning_rate: 3.0000e-05
# Epoch 12/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.8745 - loss: 0.4525
# Epoch 12: val_loss improved from 0.64693 to 0.64137, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 29s 486ms/step - accuracy: 0.8746 - loss: 0.4523 - val_accuracy: 0.8305 - val_loss: 0.6414 - learning_rate: 3.0000e-05
# Epoch 13/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9143 - loss: 0.3763
# Epoch 13: val_loss did not improve from 0.64137
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 366ms/step - accuracy: 0.9142 - loss: 0.3765 - val_accuracy: 0.8220 - val_loss: 0.6435 - learning_rate: 3.0000e-05
# Epoch 14/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9168 - loss: 0.3514
# Epoch 14: val_loss did not improve from 0.64137
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 366ms/step - accuracy: 0.9169 - loss: 0.3514 - val_accuracy: 0.8164 - val_loss: 0.6588 - learning_rate: 3.0000e-05
# Epoch 15/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9170 - loss: 0.3515
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 15: val_loss did not improve from 0.64137
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 359ms/step - accuracy: 0.9169 - loss: 0.3517 - val_accuracy: 0.8192 - val_loss: 0.6664 - learning_rate: 3.0000e-05
# Epoch 16/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9189 - loss: 0.3689
# Epoch 16: val_loss did not improve from 0.64137
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 363ms/step - accuracy: 0.9189 - loss: 0.3687 - val_accuracy: 0.8220 - val_loss: 0.6475 - learning_rate: 9.0000e-06
# Epoch 17/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9116 - loss: 0.3615
# Epoch 17: val_loss did not improve from 0.64137
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 364ms/step - accuracy: 0.9117 - loss: 0.3611 - val_accuracy: 0.8192 - val_loss: 0.6490 - learning_rate: 9.0000e-06
# Epoch 18/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9168 - loss: 0.3256
# Epoch 18: val_loss improved from 0.64137 to 0.63247, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 451ms/step - accuracy: 0.9169 - loss: 0.3258 - val_accuracy: 0.8220 - val_loss: 0.6325 - learning_rate: 9.0000e-06
# Epoch 19/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9204 - loss: 0.3251
# Epoch 19: val_loss improved from 0.63247 to 0.63227, saving model to best_resnet50_mushrooms.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 24s 403ms/step - accuracy: 0.9205 - loss: 0.3250 - val_accuracy: 0.8277 - val_loss: 0.6323 - learning_rate: 9.0000e-06
# Epoch 20/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9338 - loss: 0.3096
# Epoch 20: val_loss did not improve from 0.63227
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 364ms/step - accuracy: 0.9338 - loss: 0.3097 - val_accuracy: 0.8220 - val_loss: 0.6327 - learning_rate: 9.0000e-06
# Epoch 21/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9316 - loss: 0.3012
# Epoch 21: val_loss did not improve from 0.63227
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 363ms/step - accuracy: 0.9316 - loss: 0.3012 - val_accuracy: 0.8220 - val_loss: 0.6333 - learning_rate: 9.0000e-06
# Epoch 22/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9297 - loss: 0.3040
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
#
# Epoch 22: val_loss did not improve from 0.63227
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 365ms/step - accuracy: 0.9296 - loss: 0.3040 - val_accuracy: 0.8249 - val_loss: 0.6372 - learning_rate: 9.0000e-06
# Epoch 23/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9316 - loss: 0.2814
# Epoch 23: val_loss did not improve from 0.63227
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 364ms/step - accuracy: 0.9316 - loss: 0.2814 - val_accuracy: 0.8249 - val_loss: 0.6377 - learning_rate: 2.7000e-06
# Epoch 24/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9244 - loss: 0.2997
# Epoch 24: val_loss did not improve from 0.63227
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 362ms/step - accuracy: 0.9244 - loss: 0.2999 - val_accuracy: 0.8249 - val_loss: 0.6361 - learning_rate: 2.7000e-06
# Epoch 25/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9318 - loss: 0.2983
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
#
# Epoch 25: val_loss did not improve from 0.63227
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 364ms/step - accuracy: 0.9318 - loss: 0.2981 - val_accuracy: 0.8249 - val_loss: 0.6349 - learning_rate: 2.7000e-06
# Epoch 26/40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9288 - loss: 0.2949
# Epoch 26: val_loss did not improve from 0.63227
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 361ms/step - accuracy: 0.9287 - loss: 0.2952 - val_accuracy: 0.8249 - val_loss: 0.6337 - learning_rate: 8.1000e-07
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 19.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.9126 - loss: 0.4010
# Test accuracy: 0.8908
# Test loss: 0.4868

# %%
plot_training_history(history, model_name="ResNet")

# %%
model_resnet.save("/content/drive/MyDrive/mashrooms-vision/model-resnet.keras")

# %% [markdown]
# ##Streamlit App

# %%
# !killall ngrok

# !pip install streamlit pyngrok
# !streamlit run app_path &>/content/logs.txt &

ngrok.set_auth_token("2vAby2IpxxMqHSyp0ZtSWpTXbjX_5DGBJjggq1cyNHJfcrzLz")
print("\n\n\n", ngrok.connect(8501))
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (1.52.1)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.12/dist-packages (7.5.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.3.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.13.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
#
#
#
#  NgrokTunnel: "https://46b6e74773f3.ngrok-free.app" -> "http://localhost:8501"
