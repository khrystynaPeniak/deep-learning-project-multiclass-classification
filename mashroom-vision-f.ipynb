# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import cv2
import os

import matplotlib.pyplot as plt
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
import albumentations as A
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB3, EfficientNetB0, ResNet50
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.layers import Rescaling
#from pyngrok import ngrok

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_DIR = "/content/drive/MyDrive/mashrooms-vision/"
IMG_DIR = DATASET_DIR + "dataset/dataset/"

app_path = DATASET_DIR + "app.py"
train_df = pd.read_csv(DATASET_DIR + "train.csv")
test_df = pd.read_csv(DATASET_DIR + "test.csv")

# %%
train_df.head()
# Out:
#    Image  Mushroom
# 0      1         0
# 1      2         0
# 2      3         0
# 3      4         0
# 4      5         0

# %%
train_df.shape
# Out:
# (2365, 2)

# %%
class_counts = train_df['Mushroom'].value_counts()

plt.figure(figsize=(8,5))
plt.bar(class_counts.index.astype(str), class_counts.values)

plt.xlabel("Class")
plt.ylabel("Amout")
plt.xticks(rotation=0)
plt.show()

# %%
classes = train_df['Mushroom'].unique()

plt.figure(figsize=(12, 6))

for i, cls in enumerate(classes):
    sample = train_df[train_df['Mushroom'] == cls].iloc[4]
    img_name = f"{sample['Image']:05d}.jpg"

    img_path = os.path.join(IMG_DIR, img_name)

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.subplot(1, len(classes), i + 1)
    plt.imshow(img)
    plt.title(f"Class: {cls}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
bad = []
for file in os.listdir(IMG_DIR):
    img = cv2.imread(os.path.join(IMG_DIR, file))
    if img is None:
        bad.append(file)
bad
# Out:
# []

# %% [markdown]
# ##Data splitting for model training

# %%
train_unsampled, val = train_test_split(train_df, stratify=train_df['Mushroom'], test_size=0.2, random_state=42)
val, test = train_test_split(val, stratify=val['Mushroom'], test_size=0.25, random_state=42)

# %%
def pathify(df):
    df['Image'] = df['Image'].apply(lambda x: IMG_DIR + str(x).zfill(5) + ".jpg")
    return df

train_unsampled = pathify(train_unsampled)
val = pathify(val)
test = pathify(test)

# %%
train_unsampled
# Out:
#                                                   Image  Mushroom
# 370   /content/drive/MyDrive/mashrooms-vision/datase...         1
# 134   /content/drive/MyDrive/mashrooms-vision/datase...         0
# 904   /content/drive/MyDrive/mashrooms-vision/datase...         3
# 380   /content/drive/MyDrive/mashrooms-vision/datase...         1
# 2230  /content/drive/MyDrive/mashrooms-vision/datase...         9
# ...                                                 ...       ...
# 1351  /content/drive/MyDrive/mashrooms-vision/datase...         5
# 1004  /content/drive/MyDrive/mashrooms-vision/datase...         4
# 223   /content/drive/MyDrive/mashrooms-vision/datase...         0
# 886   /content/drive/MyDrive/mashrooms-vision/datase...         3
# 759   /content/drive/MyDrive/mashrooms-vision/datase...         3
#
# [1892 rows x 2 columns]

# %%
train_unsampled['Mushroom'].unique()
# Out:
# array([1, 0, 3, 9, 7, 2, 5, 8, 6, 4])

# %%
train_unsampled['Mushroom'].value_counts()
# Out:
# Mushroom
# 1    192
# 9    192
# 8    192
# 7    192
# 2    192
# 5    192
# 0    190
# 6    190
# 4    182
# 3    178
# Name: count, dtype: int64

# %% [markdown]
# ##Dataset preparation

# %%
BATCH_SIZE = 32
IMAGE_SIZE = (224,224)

# %%
def load_image(image_path, label):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, IMAGE_SIZE)
    #image = image / 255.0 #only for b0
    return image, label

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_unsampled['Image'].values, train_unsampled['Mushroom'].values))
train_ds = train_ds.shuffle(len(train_unsampled)).map(load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val['Image'].values, val['Mushroom'].values))
val_ds = val_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((test['Image'].values, test['Mushroom'].values))
test_ds = test_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ##Dataset inspection and sanity check

# %%
for x, y in train_ds.take(1):
    print("Batch images:", x.shape)
    print("Batch labels:", y.numpy())
# Out:
# Batch images: (32, 224, 224, 3)
# Batch labels: [3 7 5 1 0 4 5 5 1 3 2 8 2 1 5 3 1 7 7 2 5 8 6 5 0 3 1 0 3 6 7 9]

# %%
num_classes = train_unsampled['Mushroom'].nunique()
print("Number of classes:", num_classes)

print("Train classes:", train_unsampled['Mushroom'].unique())
print("Val classes:", val['Mushroom'].unique())
print("Test classes:", test['Mushroom'].unique())

print("Train distribution:\n", train_unsampled['Mushroom'].value_counts())
print("Val distribution:\n", val['Mushroom'].value_counts())
print("Test distribution:\n", test['Mushroom'].value_counts())
# Out:
# Number of classes: 10
# Train classes: [1 0 3 9 7 2 5 8 6 4]
# Val classes: [5 2 1 9 0 8 7 6 3 4]
# Test classes: [6 2 8 5 9 4 7 3 0 1]
# Train distribution:
#  Mushroom
# 1    192
# 9    192
# 8    192
# 7    192
# 2    192
# 5    192
# 0    190
# 6    190
# 4    182
# 3    178
# Name: count, dtype: int64
# Val distribution:
#  Mushroom
# 5    36
# 2    36
# 1    36
# 9    36
# 0    36
# 8    36
# 7    36
# 6    36
# 3    33
# 4    33
# Name: count, dtype: int64
# Test distribution:
#  Mushroom
# 6    12
# 2    12
# 8    12
# 5    12
# 9    12
# 4    12
# 7    12
# 0    12
# 1    12
# 3    11
# Name: count, dtype: int64

# %% [markdown]
# ##CNN models
# ####EfficientNetB0

# %%
for image, label in train_ds.take(1):
    sample_image = image[0]
    break

data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
])

augmented_images = [data_augment(tf.expand_dims(sample_image, 0)) for _ in range(7)]

plt.figure(figsize=(12,6))

plt.subplot(2,4,1)
plt.imshow(sample_image.numpy().astype("uint8"))
plt.title("Original")
plt.axis("off")

for i, img in enumerate(augmented_images):
    plt.subplot(2,4,i+2)
    plt.imshow(img[0].numpy().astype("uint8"))
    plt.title(f"Aug {i+1}")
    plt.axis("off")

plt.show()

# %%
def plot_training_history(history, model_name="Model"):
    acc = history.history.get("accuracy")
    val_acc = history.history.get("val_accuracy")
    loss = history.history.get("loss")
    val_loss = history.history.get("val_loss")

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, label="Train Accuracy")
    plt.plot(epochs, val_acc, label="Validation Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.title(f"{model_name} – Accuracy")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, label="Train Loss")
    plt.plot(epochs, val_loss, label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title(f"{model_name} – Loss")
    plt.legend()
    plt.grid(True)

# %%
data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
])

base_model_b0 = tf.keras.applications.EfficientNetB0(
    include_top=False,
    input_shape=(224,224,3),
    weights="imagenet"
)


base_model_b0.trainable = True
for layer in base_model_b0.layers[:40]:
    layer.trainable = False

model = tf.keras.Sequential([
    layers.Lambda(preprocess_input),
    data_augment,
    base_model_b0,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(10, activation="softmax")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(3e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3),
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True)
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks
)

test_loss, test_acc = model.evaluate(test_ds)
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 51s 286ms/step - accuracy: 0.1600 - loss: 2.9812 - val_accuracy: 0.4492 - val_loss: 1.8647 - learning_rate: 3.0000e-04
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.4363 - loss: 1.7275 - val_accuracy: 0.6412 - val_loss: 1.2392 - learning_rate: 3.0000e-04
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.5906 - loss: 1.2871 - val_accuracy: 0.7542 - val_loss: 0.8499 - learning_rate: 3.0000e-04
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 251ms/step - accuracy: 0.6856 - loss: 0.9544 - val_accuracy: 0.7938 - val_loss: 0.6973 - learning_rate: 3.0000e-04
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 245ms/step - accuracy: 0.7241 - loss: 0.8524 - val_accuracy: 0.8023 - val_loss: 0.6587 - learning_rate: 3.0000e-04
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 247ms/step - accuracy: 0.7518 - loss: 0.7526 - val_accuracy: 0.8164 - val_loss: 0.6213 - learning_rate: 3.0000e-04
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 243ms/step - accuracy: 0.7889 - loss: 0.6561 - val_accuracy: 0.8220 - val_loss: 0.6164 - learning_rate: 3.0000e-04
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.7961 - loss: 0.6138 - val_accuracy: 0.8249 - val_loss: 0.6243 - learning_rate: 3.0000e-04
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 249ms/step - accuracy: 0.8291 - loss: 0.4995 - val_accuracy: 0.8418 - val_loss: 0.5654 - learning_rate: 3.0000e-04
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 248ms/step - accuracy: 0.8506 - loss: 0.4942 - val_accuracy: 0.8503 - val_loss: 0.5332 - learning_rate: 3.0000e-04
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 244ms/step - accuracy: 0.8609 - loss: 0.4080 - val_accuracy: 0.8446 - val_loss: 0.5275 - learning_rate: 3.0000e-04
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.8870 - loss: 0.3430 - val_accuracy: 0.8559 - val_loss: 0.4982 - learning_rate: 3.0000e-04
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 246ms/step - accuracy: 0.8874 - loss: 0.3351 - val_accuracy: 0.8362 - val_loss: 0.5577 - learning_rate: 3.0000e-04
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 265ms/step - accuracy: 0.8881 - loss: 0.3331 - val_accuracy: 0.8333 - val_loss: 0.5073 - learning_rate: 3.0000e-04
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 242ms/step - accuracy: 0.9210 - loss: 0.2646 - val_accuracy: 0.8475 - val_loss: 0.5394 - learning_rate: 3.0000e-04
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 241ms/step - accuracy: 0.9248 - loss: 0.2519 - val_accuracy: 0.8362 - val_loss: 0.5352 - learning_rate: 9.0000e-05
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 243ms/step - accuracy: 0.9285 - loss: 0.2190 - val_accuracy: 0.8390 - val_loss: 0.5380 - learning_rate: 9.0000e-05
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 245ms/step - accuracy: 0.9269 - loss: 0.2396 - val_accuracy: 0.8503 - val_loss: 0.5303 - learning_rate: 9.0000e-05
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 265ms/step - accuracy: 0.9364 - loss: 0.2051 - val_accuracy: 0.8475 - val_loss: 0.5244 - learning_rate: 2.7000e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9090 - loss: 0.3857
# Test accuracy: 0.8739495873451233
# Test loss: 0.44129297137260437

# %%
plot_training_history(history, model_name="EfficientNetB0")

# %%
model.save("/content/drive/MyDrive/mashrooms-vision/model-b0.keras")

# %% [markdown]
# ####EfficientNetB3

# %%
data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1),
])

base_model = EfficientNetB3(
    include_top=False,
    input_shape=(224,224,3),
    weights="imagenet"
)
base_model.trainable = False

model_b3 = tf.keras.Sequential([
    layers.Lambda(preprocess_input),
    data_augment,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(10, activation="softmax")
])

model_b3.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


callbacks = [
    ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, verbose=1),
    EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True, verbose=1),
    ModelCheckpoint("best_efficientnetb3.keras", save_best_only=True, verbose=1)
]

history = model_b3.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks,
    verbose=1
)

base_model.trainable = True
for layer in base_model.layers[:-100]:
    layer.trainable = False

model_b3.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history_ft = model_b3.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=callbacks,
    verbose=1
)

test_loss, test_acc = model_b3.evaluate(test_ds)
print("Test accuracy:", test_acc)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.2871 - loss: 2.4329
# Epoch 1: val_loss improved from inf to 1.52911, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 33s 287ms/step - accuracy: 0.2912 - loss: 2.4164 - val_accuracy: 0.5650 - val_loss: 1.5291 - learning_rate: 0.0010
# Epoch 2/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6021 - loss: 1.2663
# Epoch 2: val_loss improved from 1.52911 to 1.15410, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 192ms/step - accuracy: 0.6024 - loss: 1.2647 - val_accuracy: 0.6525 - val_loss: 1.1541 - learning_rate: 0.0010
# Epoch 3/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6838 - loss: 1.0175
# Epoch 3: val_loss improved from 1.15410 to 0.88074, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 191ms/step - accuracy: 0.6836 - loss: 1.0171 - val_accuracy: 0.7260 - val_loss: 0.8807 - learning_rate: 0.0010
# Epoch 4/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7259 - loss: 0.9141
# Epoch 4: val_loss improved from 0.88074 to 0.79664, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 190ms/step - accuracy: 0.7257 - loss: 0.9137 - val_accuracy: 0.7345 - val_loss: 0.7966 - learning_rate: 0.0010
# Epoch 5/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.7378 - loss: 0.8519
# Epoch 5: val_loss improved from 0.79664 to 0.79598, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.7379 - loss: 0.8515 - val_accuracy: 0.7373 - val_loss: 0.7960 - learning_rate: 0.0010
# Epoch 6/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7816 - loss: 0.7431
# Epoch 6: val_loss improved from 0.79598 to 0.76110, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 193ms/step - accuracy: 0.7813 - loss: 0.7440 - val_accuracy: 0.7797 - val_loss: 0.7611 - learning_rate: 0.0010
# Epoch 7/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7812 - loss: 0.6986
# Epoch 7: val_loss improved from 0.76110 to 0.73971, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 186ms/step - accuracy: 0.7816 - loss: 0.6986 - val_accuracy: 0.7712 - val_loss: 0.7397 - learning_rate: 0.0010
# Epoch 8/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8004 - loss: 0.6924
# Epoch 8: val_loss improved from 0.73971 to 0.73429, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 189ms/step - accuracy: 0.8002 - loss: 0.6927 - val_accuracy: 0.7881 - val_loss: 0.7343 - learning_rate: 0.0010
# Epoch 9/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8149 - loss: 0.6233
# Epoch 9: val_loss improved from 0.73429 to 0.73048, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 192ms/step - accuracy: 0.8148 - loss: 0.6238 - val_accuracy: 0.7853 - val_loss: 0.7305 - learning_rate: 0.0010
# Epoch 10/10
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8020 - loss: 0.6308
# Epoch 10: val_loss improved from 0.73048 to 0.71754, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 12s 193ms/step - accuracy: 0.8023 - loss: 0.6306 - val_accuracy: 0.7853 - val_loss: 0.7175 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# Epoch 1/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6534 - loss: 1.1007
# Epoch 1: val_loss did not improve from 0.71754
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 48s 314ms/step - accuracy: 0.6540 - loss: 1.0991 - val_accuracy: 0.7938 - val_loss: 0.7907 - learning_rate: 1.0000e-04
# Epoch 2/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.7830 - loss: 0.6947
# Epoch 2: val_loss did not improve from 0.71754
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 233ms/step - accuracy: 0.7832 - loss: 0.6944 - val_accuracy: 0.8107 - val_loss: 0.7611 - learning_rate: 1.0000e-04
# Epoch 3/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8432 - loss: 0.5402
# Epoch 3: val_loss improved from 0.71754 to 0.68976, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 258ms/step - accuracy: 0.8431 - loss: 0.5404 - val_accuracy: 0.8333 - val_loss: 0.6898 - learning_rate: 1.0000e-04
# Epoch 4/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8800 - loss: 0.4458
# Epoch 4: val_loss improved from 0.68976 to 0.65080, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 261ms/step - accuracy: 0.8799 - loss: 0.4464 - val_accuracy: 0.8446 - val_loss: 0.6508 - learning_rate: 1.0000e-04
# Epoch 5/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8882 - loss: 0.4134
# Epoch 5: val_loss improved from 0.65080 to 0.64392, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.8882 - loss: 0.4133 - val_accuracy: 0.8475 - val_loss: 0.6439 - learning_rate: 1.0000e-04
# Epoch 6/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8951 - loss: 0.3789
# Epoch 6: val_loss improved from 0.64392 to 0.63895, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.8951 - loss: 0.3789 - val_accuracy: 0.8390 - val_loss: 0.6389 - learning_rate: 1.0000e-04
# Epoch 7/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9278 - loss: 0.3121
# Epoch 7: val_loss improved from 0.63895 to 0.63534, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 276ms/step - accuracy: 0.9278 - loss: 0.3119 - val_accuracy: 0.8418 - val_loss: 0.6353 - learning_rate: 1.0000e-04
# Epoch 8/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9327 - loss: 0.2910
# Epoch 8: val_loss improved from 0.63534 to 0.62887, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 267ms/step - accuracy: 0.9327 - loss: 0.2910 - val_accuracy: 0.8390 - val_loss: 0.6289 - learning_rate: 1.0000e-04
# Epoch 9/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9291 - loss: 0.2969
# Epoch 9: val_loss improved from 0.62887 to 0.61506, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9292 - loss: 0.2967 - val_accuracy: 0.8503 - val_loss: 0.6151 - learning_rate: 1.0000e-04
# Epoch 10/30
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9363 - loss: 0.2721
# Epoch 10: val_loss improved from 0.61506 to 0.60639, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 255ms/step - accuracy: 0.9365 - loss: 0.2717 - val_accuracy: 0.8503 - val_loss: 0.6064 - learning_rate: 1.0000e-04
# Epoch 11/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9526 - loss: 0.2407
# Epoch 11: val_loss improved from 0.60639 to 0.58537, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 15s 253ms/step - accuracy: 0.9526 - loss: 0.2409 - val_accuracy: 0.8644 - val_loss: 0.5854 - learning_rate: 1.0000e-04
# Epoch 12/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9634 - loss: 0.1964
# Epoch 12: val_loss did not improve from 0.58537
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.9634 - loss: 0.1967 - val_accuracy: 0.8559 - val_loss: 0.5865 - learning_rate: 1.0000e-04
# Epoch 13/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9562 - loss: 0.2203
# Epoch 13: val_loss did not improve from 0.58537
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9563 - loss: 0.2201 - val_accuracy: 0.8559 - val_loss: 0.5919 - learning_rate: 1.0000e-04
# Epoch 14/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9518 - loss: 0.2274
# Epoch 14: val_loss improved from 0.58537 to 0.56541, saving model to best_efficientnetb3.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 261ms/step - accuracy: 0.9520 - loss: 0.2272 - val_accuracy: 0.8531 - val_loss: 0.5654 - learning_rate: 1.0000e-04
# Epoch 15/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9597 - loss: 0.1951
# Epoch 15: val_loss did not improve from 0.56541
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9598 - loss: 0.1950 - val_accuracy: 0.8475 - val_loss: 0.5971 - learning_rate: 1.0000e-04
# Epoch 16/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9748 - loss: 0.1843
# Epoch 16: val_loss did not improve from 0.56541
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9748 - loss: 0.1842 - val_accuracy: 0.8559 - val_loss: 0.5872 - learning_rate: 1.0000e-04
# Epoch 17/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9668 - loss: 0.1834
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 17: val_loss did not improve from 0.56541
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9668 - loss: 0.1835 - val_accuracy: 0.8559 - val_loss: 0.5861 - learning_rate: 1.0000e-04
# Epoch 18/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9768 - loss: 0.1674
# Epoch 18: val_loss did not improve from 0.56541
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.9767 - loss: 0.1675 - val_accuracy: 0.8616 - val_loss: 0.5779 - learning_rate: 3.0000e-05
# Epoch 19/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9849 - loss: 0.1471
# Epoch 19: val_loss did not improve from 0.56541
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9848 - loss: 0.1471 - val_accuracy: 0.8644 - val_loss: 0.5718 - learning_rate: 3.0000e-05
# Epoch 20/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9711 - loss: 0.1835
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 20: val_loss did not improve from 0.56541
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9712 - loss: 0.1832 - val_accuracy: 0.8616 - val_loss: 0.5723 - learning_rate: 3.0000e-05
# Epoch 21/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9731 - loss: 0.1630
# Epoch 21: val_loss did not improve from 0.56541
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9731 - loss: 0.1631 - val_accuracy: 0.8616 - val_loss: 0.5723 - learning_rate: 9.0000e-06
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - accuracy: 0.9185 - loss: 0.3627
# Test accuracy: 0.9159663915634155

# %%
model_b3.save("/content/drive/MyDrive/mashrooms-vision/model-b3-100.keras")

# %% [markdown]
# ####ResNet

# %%
data_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

base_model = ResNet50(
    include_top=False,
    input_shape=(224,224,3),
    weights="imagenet"
)

base_model.trainable = True
for layer in base_model.layers[:-100]:
    layer.trainable = False

inputs = tf.keras.Input(shape=(224,224,3))
x = data_augment(inputs)
x = tf.keras.applications.resnet.preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(10, activation="softmax")(x)

model_resnet = tf.keras.Model(inputs, outputs, name="ResNet50-Mushroom")


model_resnet.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, verbose=1)
early_stop = EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True, verbose=1)
checkpoint = ModelCheckpoint("best_resnet.keras", save_best_only=True, verbose=1)

callbacks = [reduce_lr, early_stop, checkpoint]

history = model_resnet.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks,
    verbose=1
)

test_loss, test_acc = model_resnet.evaluate(test_ds)
print("Test accuracy:", test_acc)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.1705 - loss: 2.9302
# Epoch 1: val_loss improved from inf to 1.56852, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 57s 482ms/step - accuracy: 0.1720 - loss: 2.9238 - val_accuracy: 0.4774 - val_loss: 1.5685 - learning_rate: 1.0000e-04
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.4755 - loss: 1.6926
# Epoch 2: val_loss improved from 1.56852 to 1.23340, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 373ms/step - accuracy: 0.4764 - loss: 1.6899 - val_accuracy: 0.6186 - val_loss: 1.2334 - learning_rate: 1.0000e-04
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.6234 - loss: 1.1884
# Epoch 3: val_loss improved from 1.23340 to 0.87275, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 45s 445ms/step - accuracy: 0.6237 - loss: 1.1876 - val_accuracy: 0.7571 - val_loss: 0.8728 - learning_rate: 1.0000e-04
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.7128 - loss: 0.9108
# Epoch 4: val_loss improved from 0.87275 to 0.76423, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 25s 410ms/step - accuracy: 0.7131 - loss: 0.9101 - val_accuracy: 0.7853 - val_loss: 0.7642 - learning_rate: 1.0000e-04
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.7820 - loss: 0.7433
# Epoch 5: val_loss did not improve from 0.76423
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 322ms/step - accuracy: 0.7819 - loss: 0.7435 - val_accuracy: 0.7825 - val_loss: 0.7780 - learning_rate: 1.0000e-04
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8113 - loss: 0.6398
# Epoch 6: val_loss improved from 0.76423 to 0.74388, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 28s 461ms/step - accuracy: 0.8116 - loss: 0.6392 - val_accuracy: 0.7994 - val_loss: 0.7439 - learning_rate: 1.0000e-04
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.8405 - loss: 0.5936
# Epoch 7: val_loss improved from 0.74388 to 0.62280, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 25s 410ms/step - accuracy: 0.8404 - loss: 0.5935 - val_accuracy: 0.8305 - val_loss: 0.6228 - learning_rate: 1.0000e-04
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.8506 - loss: 0.5371
# Epoch 8: val_loss did not improve from 0.62280
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 36s 320ms/step - accuracy: 0.8506 - loss: 0.5369 - val_accuracy: 0.8249 - val_loss: 0.6869 - learning_rate: 1.0000e-04
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.8686 - loss: 0.4832
# Epoch 9: val_loss improved from 0.62280 to 0.60979, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 24s 397ms/step - accuracy: 0.8686 - loss: 0.4836 - val_accuracy: 0.8475 - val_loss: 0.6098 - learning_rate: 1.0000e-04
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.8741 - loss: 0.4714
# Epoch 10: val_loss did not improve from 0.60979
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 320ms/step - accuracy: 0.8739 - loss: 0.4720 - val_accuracy: 0.8333 - val_loss: 0.6289 - learning_rate: 1.0000e-04
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.8879 - loss: 0.4216
# Epoch 11: val_loss improved from 0.60979 to 0.56554, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 354ms/step - accuracy: 0.8880 - loss: 0.4216 - val_accuracy: 0.8503 - val_loss: 0.5655 - learning_rate: 1.0000e-04
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.9094 - loss: 0.3575
# Epoch 12: val_loss improved from 0.56554 to 0.54674, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 25s 408ms/step - accuracy: 0.9095 - loss: 0.3574 - val_accuracy: 0.8559 - val_loss: 0.5467 - learning_rate: 1.0000e-04
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9207 - loss: 0.3177
# Epoch 13: val_loss did not improve from 0.54674
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 325ms/step - accuracy: 0.9208 - loss: 0.3179 - val_accuracy: 0.8616 - val_loss: 0.5722 - learning_rate: 1.0000e-04
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9203 - loss: 0.3312
# Epoch 14: val_loss did not improve from 0.54674
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 320ms/step - accuracy: 0.9201 - loss: 0.3313 - val_accuracy: 0.8531 - val_loss: 0.5828 - learning_rate: 1.0000e-04
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9199 - loss: 0.3483
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
#
# Epoch 15: val_loss did not improve from 0.54674
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.9199 - loss: 0.3483 - val_accuracy: 0.8107 - val_loss: 0.7898 - learning_rate: 1.0000e-04
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.8867 - loss: 0.4197
# Epoch 16: val_loss did not improve from 0.54674
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 317ms/step - accuracy: 0.8868 - loss: 0.4192 - val_accuracy: 0.8333 - val_loss: 0.6862 - learning_rate: 3.0000e-05
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9333 - loss: 0.3146
# Epoch 17: val_loss did not improve from 0.54674
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.9333 - loss: 0.3143 - val_accuracy: 0.8588 - val_loss: 0.5691 - learning_rate: 3.0000e-05
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9402 - loss: 0.2753
# Epoch 18: val_loss improved from 0.54674 to 0.54416, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 366ms/step - accuracy: 0.9402 - loss: 0.2753 - val_accuracy: 0.8616 - val_loss: 0.5442 - learning_rate: 3.0000e-05
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9462 - loss: 0.2573
# Epoch 19: val_loss improved from 0.54416 to 0.53376, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 26s 432ms/step - accuracy: 0.9462 - loss: 0.2573 - val_accuracy: 0.8672 - val_loss: 0.5338 - learning_rate: 3.0000e-05
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9413 - loss: 0.2653
# Epoch 20: val_loss did not improve from 0.53376
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 321ms/step - accuracy: 0.9415 - loss: 0.2648 - val_accuracy: 0.8785 - val_loss: 0.5361 - learning_rate: 3.0000e-05
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9540 - loss: 0.2413
# Epoch 21: val_loss improved from 0.53376 to 0.52274, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 25s 421ms/step - accuracy: 0.9539 - loss: 0.2413 - val_accuracy: 0.8729 - val_loss: 0.5227 - learning_rate: 3.0000e-05
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9582 - loss: 0.2189
# Epoch 22: val_loss improved from 0.52274 to 0.51643, saving model to best_resnet.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 22s 373ms/step - accuracy: 0.9582 - loss: 0.2191 - val_accuracy: 0.8701 - val_loss: 0.5164 - learning_rate: 3.0000e-05
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9607 - loss: 0.1994
# Epoch 23: val_loss did not improve from 0.51643
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 319ms/step - accuracy: 0.9608 - loss: 0.1995 - val_accuracy: 0.8757 - val_loss: 0.5226 - learning_rate: 3.0000e-05
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9545 - loss: 0.2320
# Epoch 24: val_loss did not improve from 0.51643
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 338ms/step - accuracy: 0.9545 - loss: 0.2321 - val_accuracy: 0.8559 - val_loss: 0.5754 - learning_rate: 3.0000e-05
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9620 - loss: 0.2073
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
#
# Epoch 25: val_loss did not improve from 0.51643
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 318ms/step - accuracy: 0.9619 - loss: 0.2075 - val_accuracy: 0.8785 - val_loss: 0.5415 - learning_rate: 3.0000e-05
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9564 - loss: 0.2054
# Epoch 26: val_loss did not improve from 0.51643
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.9564 - loss: 0.2054 - val_accuracy: 0.8785 - val_loss: 0.5488 - learning_rate: 9.0000e-06
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9665 - loss: 0.1927
# Epoch 27: val_loss did not improve from 0.51643
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 319ms/step - accuracy: 0.9665 - loss: 0.1927 - val_accuracy: 0.8729 - val_loss: 0.5514 - learning_rate: 9.0000e-06
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9602 - loss: 0.2082
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
#
# Epoch 28: val_loss did not improve from 0.51643
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 324ms/step - accuracy: 0.9602 - loss: 0.2080 - val_accuracy: 0.8729 - val_loss: 0.5503 - learning_rate: 9.0000e-06
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9680 - loss: 0.1934
# Epoch 29: val_loss did not improve from 0.51643
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 319ms/step - accuracy: 0.9679 - loss: 0.1937 - val_accuracy: 0.8729 - val_loss: 0.5501 - learning_rate: 2.7000e-06
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 22.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 333ms/step - accuracy: 0.8375 - loss: 0.7143
# Test accuracy: 0.8151260614395142

# %%
model_resnet.save("/content/drive/MyDrive/mashrooms-vision/model-res.keras")

# %% [markdown]
# ##Streamlit App

# %%
# !killall ngrok

# !pip install streamlit pyngrok
# !streamlit run app_path &>/content/logs.txt &

ngrok.set_auth_token("2vAby2IpxxMqHSyp0ZtSWpTXbjX_5DGBJjggq1cyNHJfcrzLz")
print("\n\n\n", ngrok.connect(8501))
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (1.52.1)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.12/dist-packages (7.5.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.3.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.13.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
#
#
#
#  NgrokTunnel: "https://46b6e74773f3.ngrok-free.app" -> "http://localhost:8501"
